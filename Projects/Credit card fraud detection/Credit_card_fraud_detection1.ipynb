# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/credit.csv')

# %%
df.head()
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1    20000.0  2.0        2.0       1.0  24.0    2.0    2.0   -1.0   -1.0
# 1   2   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0    0.0    0.0
# 2   3    90000.0  2.0        2.0       2.0  34.0    0.0    0.0    0.0    0.0
# 3   4    50000.0  2.0        2.0       1.0  37.0    0.0    0.0    0.0    0.0
# 4   5    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0   -1.0    0.0
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 0       0.0       0.0       0.0                         1.0
# 1    1000.0       0.0    2000.0                         1.0
# 2    1000.0    1000.0    5000.0                         0.0
# 3    1100.0    1069.0    1000.0                         0.0
# 4    9000.0     689.0     679.0                         0.0
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22041 entries, 0 to 22040
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          22041 non-null  int64
#  1   LIMIT_BAL                   22041 non-null  float64
#  2   SEX                         22040 non-null  float64
#  3   EDUCATION                   22040 non-null  float64
#  4   MARRIAGE                    22040 non-null  float64
#  5   AGE                         22040 non-null  float64
#  6   PAY_0                       22040 non-null  float64
#  7   PAY_2                       22040 non-null  float64
#  8   PAY_3                       22040 non-null  float64
#  9   PAY_4                       22040 non-null  float64
#  10  PAY_5                       22040 non-null  float64
#  11  PAY_6                       22040 non-null  float64
#  12  BILL_AMT1                   22040 non-null  float64
#  13  BILL_AMT2                   22040 non-null  float64
#  14  BILL_AMT3                   22040 non-null  float64
#  15  BILL_AMT4                   22040 non-null  float64
#  16  BILL_AMT5                   22040 non-null  float64
#  17  BILL_AMT6                   22040 non-null  float64
#  18  PAY_AMT1                    22040 non-null  float64
#  19  PAY_AMT2                    22040 non-null  float64
#  20  PAY_AMT3                    22040 non-null  float64
#  21  PAY_AMT4                    22040 non-null  float64
#  22  PAY_AMT5                    22040 non-null  float64
#  23  PAY_AMT6                    22040 non-null  float64
#  24  default.payment.next.month  22040 non-null  float64
# dtypes: float64(24), int64(1)
# memory usage: 4.2 MB

# %%
df.describe()
# Out:
#                  ID       LIMIT_BAL           SEX     EDUCATION      MARRIAGE  \
# count  22041.000000    22041.000000  22040.000000  22040.000000  22040.000000
# mean   11021.000000   162927.892564      1.602042      1.841742      1.561933
# std     6362.832978   128591.879082      0.489488      0.775434      0.521573
# min        1.000000    10000.000000      1.000000      0.000000      0.000000
# 25%     5511.000000    50000.000000      1.000000      1.000000      1.000000
# 50%    11021.000000   130000.000000      2.000000      2.000000      2.000000
# 75%    16531.000000   230000.000000      2.000000      2.000000      2.000000
# max    22041.000000  1000000.000000      2.000000      6.000000      3.000000
#
#                 AGE         PAY_0         PAY_2         PAY_3         PAY_4  \
# count  22040.000000  22040.000000  22040.000000  22040.000000  22040.000000
# mean      35.309574      0.019419     -0.103312     -0.134437     -0.194283
# std        9.351772      1.121497      1.199501      1.204877      1.166055
# min       21.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       28.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%       34.000000      0.000000      0.000000      0.000000      0.000000
# 75%       41.000000      0.000000      0.000000      0.000000      0.000000
# max       79.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   22040.000000   22040.000000   22040.000000   22040.000000
# mean   ...   41962.340926   39767.444419   38354.095100    5504.820191
# std    ...   62164.659744   59661.773802   58799.252592   15155.895218
# min    ... -170000.000000  -46627.000000 -339603.000000       0.000000
# 25%    ...    2400.000000    1793.500000    1243.000000    1000.000000
# 50%    ...   19051.000000   18263.500000   17164.000000    2091.500000
# 75%    ...   51715.500000   49630.000000   48754.500000    5000.000000
# max    ...  891586.000000  927171.000000  961664.000000  505000.000000
#
#            PAY_AMT2       PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  2.204000e+04   22040.000000   22040.000000   22040.000000
# mean   5.788233e+03    4853.098503    4692.252632    4687.957078
# std    2.127658e+04   16026.840108   14864.551789   15020.778132
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    7.800000e+02     350.750000     270.000000     234.750000
# 50%    2.000000e+03    1649.500000    1500.000000    1500.000000
# 75%    5.000000e+03    4137.250000    4000.000000    4000.000000
# max    1.684259e+06  896040.000000  497000.000000  417990.000000
#
#             PAY_AMT6  default.payment.next.month
# count   22040.000000                22040.000000
# mean     5092.812568                    0.227450
# std     17390.775599                    0.419195
# min         0.000000                    0.000000
# 25%        32.000000                    0.000000
# 50%      1441.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 25 columns]

# %%
#dont need ID
df=df.drop('ID', axis=1)

# %%
df.head()
# Out:
#    LIMIT_BAL  SEX  EDUCATION  MARRIAGE   AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0    20000.0  2.0        2.0       1.0  24.0    2.0    2.0   -1.0   -1.0
# 1   120000.0  2.0        2.0       2.0  26.0   -1.0    2.0    0.0    0.0
# 2    90000.0  2.0        2.0       2.0  34.0    0.0    0.0    0.0    0.0
# 3    50000.0  2.0        2.0       1.0  37.0    0.0    0.0    0.0    0.0
# 4    50000.0  1.0        2.0       1.0  57.0   -1.0    0.0   -1.0    0.0
#
#    PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# 0   -2.0  ...        0.0        0.0        0.0       0.0     689.0       0.0
# 1    0.0  ...     3272.0     3455.0     3261.0       0.0    1000.0    1000.0
# 2    0.0  ...    14331.0    14948.0    15549.0    1518.0    1500.0    1000.0
# 3    0.0  ...    28314.0    28959.0    29547.0    2000.0    2019.0    1200.0
# 4    0.0  ...    20940.0    19146.0    19131.0    2000.0   36681.0   10000.0
#
#    PAY_AMT4  PAY_AMT5  PAY_AMT6  default.payment.next.month
# 0       0.0       0.0       0.0                         1.0
# 1    1000.0       0.0    2000.0                         1.0
# 2    1000.0    1000.0    5000.0                         0.0
# 3    1100.0    1069.0    1000.0                         0.0
# 4    9000.0     689.0     679.0                         0.0
#
# [5 rows x 24 columns]

# %%
# Checking for null values
df.isnull().sum()
# Out:
# LIMIT_BAL                     0
# SEX                           1
# EDUCATION                     1
# MARRIAGE                      1
# AGE                           1
# PAY_0                         1
# PAY_2                         1
# PAY_3                         1
# PAY_4                         1
# PAY_5                         1
# PAY_6                         1
# BILL_AMT1                     1
# BILL_AMT2                     1
# BILL_AMT3                     1
# BILL_AMT4                     1
# BILL_AMT5                     1
# BILL_AMT6                     1
# PAY_AMT1                      1
# PAY_AMT2                      1
# PAY_AMT3                      1
# PAY_AMT4                      1
# PAY_AMT5                      1
# PAY_AMT6                      1
# default.payment.next.month    1
# dtype: int64

# %%
#UNIVARIATE ANALYSIS: Looking at the type of data present in different columns
cat_cols=['SEX','EDUCATION','MARRIAGE','default.payment.next.month']

fig,ax=plt.subplots(1,4,figsize=(25,5))

for cols,subplots in zip(cat_cols,ax.flatten()):
    sns.countplot(x=df[cols],ax=subplots)

#SEX: Gender (1=male, 2=female)
#EDUCATION: (1=graduate school, 2=university, 3=high school, 4=others, 5=unknown, 6=unknown)
#MARRIAGE: Marital status (1=married, 2=single, 3=others)
#Default payment (1=yes, 0=no)

# %%
# Vizualizing the imbalance

yes=(((df['default.payment.next.month']==1).sum())/len(df['default.payment.next.month']))*100
no=(((df['default.payment.next.month']==0).sum())/len(df['default.payment.next.month']))*100

x=[yes,no]

plt.pie(x,labels=['Yes','No'],colors=['red', 'green'],radius=2,autopct='%1.0f%%')
plt.title('default.payment.next.month')
plt.show()

# %%
df['default.payment.next.month'].value_counts(normalize=True)
# Out:
# 0.0    0.77255
# 1.0    0.22745
# Name: default.payment.next.month, dtype: float64

# %%
X=df.drop('default.payment.next.month',axis=1)
y=df['default.payment.next.month']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.30,random_state=42)

# %%
from sklearn.ensemble import RandomForestClassifier
rfc=RandomForestClassifier()

# %%
# !pip install sklearn
# Out:
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
import pandas as pd

X_train = pd.DataFrame(X_train)
y_train = pd.DataFrame(y_train)

missing_values = X_train.isnull().sum().sum()

if missing_values > 0:
    print("There are missing values in the data.")
# Out:
# There are missing values in the data.

# %%
# Drop rows with missing values
X_train = X_train.dropna()
y_train = y_train.dropna()

# Impute missing values
from sklearn.impute import SimpleImputer

imputer = SimpleImputer(strategy="mean")

X_train = imputer.fit_transform(X_train)

# %%
rfc = RandomForestClassifier()
model = rfc.fit(X_train, y_train)
# Out:
# <ipython-input-21-10f084473d03>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model = rfc.fit(X_train, y_train)

# %%
model=rfc.fit(X_train,y_train)
# Out:
# <ipython-input-22-c799c422264f>:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   model=rfc.fit(X_train,y_train)

# %%
predictions=model.predict(X_test)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning: X has feature names, but RandomForestClassifier was fitted without feature names
#   warnings.warn(

# %%
from sklearn.metrics import classification_report,confusion_matrix,accuracy_score
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       0.84      0.94      0.89      5147
#          1.0       0.63      0.37      0.47      1466
#
#     accuracy                           0.81      6613
#    macro avg       0.74      0.66      0.68      6613
# weighted avg       0.79      0.81      0.79      6613
